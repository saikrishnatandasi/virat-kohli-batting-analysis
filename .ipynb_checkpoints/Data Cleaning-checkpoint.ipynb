# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Cleaning of ODI Stats

# %%
df = pd.read_csv("virat_odi_stats.csv")
df
# Out:
#     Runs Mins   BF 4s 6s      SR Pos Dismissal Inns     Opposition  \
# 0     12   33   22  1  0   54.54   2       lbw    1    v Sri Lanka
# 1     37   82   67  6  0   55.22   2    caught    2    v Sri Lanka
# 2     25   40   38  4  0   65.78   1   run out    1    v Sri Lanka
# 3     54   87   66  7  0   81.81   1    bowled    1    v Sri Lanka
# 4     31   45   46  3  1   67.39   1       lbw    2    v Sri Lanka
# ..   ...  ...  ... .. ..     ...  ..       ...  ...            ...
# 290  117  149  113  9  2  103.53   3    caught    1  v New Zealand
# 291   54   99   63  4  0   85.71   3    bowled    1    v Australia
# 292   24   42   32  2  0   75.00   3       lbw    2    v Sri Lanka
# 293   14   27   19  2  0   73.68   3       lbw    2    v Sri Lanka
# 294   20   29   18  4  0  111.11   3       lbw    2    v Sri Lanka
#
#             Ground   Start Date   Scorecard
# 0         Dambulla  18 Aug 2008  ODI # 2742
# 1         Dambulla  20 Aug 2008  ODI # 2745
# ...

# %%
df.head()
# Out:
#   Runs Mins  BF 4s 6s     SR Pos Dismissal Inns   Opposition         Ground  \
# 0   12   33  22  1  0  54.54   2       lbw    1  v Sri Lanka       Dambulla
# 1   37   82  67  6  0  55.22   2    caught    2  v Sri Lanka       Dambulla
# 2   25   40  38  4  0  65.78   1   run out    1  v Sri Lanka  Colombo (RPS)
# 3   54   87  66  7  0  81.81   1    bowled    1  v Sri Lanka  Colombo (RPS)
# 4   31   45  46  3  1  67.39   1       lbw    2  v Sri Lanka  Colombo (RPS)
#
#     Start Date   Scorecard
# 0  18 Aug 2008  ODI # 2742
# 1  20 Aug 2008  ODI # 2745
# 2  24 Aug 2008  ODI # 2750
# 3  27 Aug 2008  ODI # 2755
# 4  29 Aug 2008  ODI # 2756

# %%
df.tail()
# Out:
#     Runs Mins   BF 4s 6s      SR Pos Dismissal Inns     Opposition  \
# 290  117  149  113  9  2  103.53   3    caught    1  v New Zealand
# 291   54   99   63  4  0   85.71   3    bowled    1    v Australia
# 292   24   42   32  2  0   75.00   3       lbw    2    v Sri Lanka
# 293   14   27   19  2  0   73.68   3       lbw    2    v Sri Lanka
# 294   20   29   18  4  0  111.11   3       lbw    2    v Sri Lanka
#
#             Ground   Start Date   Scorecard
# 290       Wankhede  15 Nov 2023  ODI # 4703
# 291      Ahmedabad  19 Nov 2023  ODI # 4705
# 292  Colombo (RPS)   2 Aug 2024  ODI # 4752
# 293  Colombo (RPS)   4 Aug 2024  ODI # 4753
# 294  Colombo (RPS)   7 Aug 2024  ODI # 4754

# %%
df.shape
# Out:
# (295, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Runs        295 non-null    object
#  1   Mins        295 non-null    object
#  2   BF          295 non-null    object
#  3   4s          295 non-null    object
#  4   6s          295 non-null    object
#  5   SR          295 non-null    object
#  6   Pos         295 non-null    object
#  7   Dismissal   295 non-null    object
#  8   Inns        295 non-null    object
#  9   Opposition  295 non-null    object
#  10  Ground      295 non-null    object
#  11  Start Date  295 non-null    object
#  12  Scorecard   295 non-null    object
# dtypes: object(13)
# memory usage: 30.1+ KB

# %%
df.dtypes
# Out:
# Runs          object
# Mins          object
# BF            object
# 4s            object
# 6s            object
# SR            object
# Pos           object
# Dismissal     object
# Inns          object
# Opposition    object
# Ground        object
# Start Date    object
# Scorecard     object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Runs          0
# Mins          0
# BF            0
# 4s            0
# 6s            0
# SR            0
# Pos           0
# Dismissal     0
# Inns          0
# Opposition    0
# Ground        0
# Start Date    0
# Scorecard     0
# dtype: int64

# %%
df[df["Runs"].apply(lambda x : "*" in x)]
# Out:
#      Runs Mins   BF  4s 6s      SR Pos Dismissal Inns      Opposition  \
# 5      2*    6    2   0  0  100.00   7   not out    1     v Sri Lanka
# 8     79*  121  104   9  2   75.96   4   not out    2   v West Indies
# 17    71*   98   68   9  0  104.41   3   not out    2     v Sri Lanka
# 18   102*  128   95  11  0  107.36   3   not out    2    v Bangladesh
# 37    63*   83   70   6  2   90.00   3   not out    2   v New Zealand
# 43    87*  126   92   7  2   94.56   3   not out    2  v South Africa
# 45   100*  113   83   8  2  120.48   4   not out    1    v Bangladesh
# 65   112*  134   98  16  0  114.28   4   not out    2       v England
# 67    86*    -   99  11  0   86.86   4   not out    2       v England
# 72    23*   15   11   3  0  209.09   6   not out    1   v West Indies
# 81   133*  133   86  16  2  154.65   4   not out    2     v Sri Lanka
# 88   128*  187  119  12  1  107.56   3   not out    2     v Sri Lanka
# ...

# %%
df["is_not_out"] = df["Dismissal"].apply(lambda x : 1 if x == "not out" else 0)

# %%
df[df["is_not_out"] == 1]
# Out:
#      Runs Mins   BF  4s 6s      SR Pos Dismissal Inns      Opposition  \
# 5      2*    6    2   0  0  100.00   7   not out    1     v Sri Lanka
# 8     79*  121  104   9  2   75.96   4   not out    2   v West Indies
# 17    71*   98   68   9  0  104.41   3   not out    2     v Sri Lanka
# 18   102*  128   95  11  0  107.36   3   not out    2    v Bangladesh
# 37    63*   83   70   6  2   90.00   3   not out    2   v New Zealand
# 43    87*  126   92   7  2   94.56   3   not out    2  v South Africa
# 45   100*  113   83   8  2  120.48   4   not out    1    v Bangladesh
# 65   112*  134   98  16  0  114.28   4   not out    2       v England
# 67    86*    -   99  11  0   86.86   4   not out    2       v England
# 72    23*   15   11   3  0  209.09   6   not out    1   v West Indies
# 81   133*  133   86  16  2  154.65   4   not out    2     v Sri Lanka
# 88   128*  187  119  12  1  107.56   3   not out    2     v Sri Lanka
# ...

# %%
x= df["Dismissal"].value_counts()
x
# Out:
# caught        168
# not out        44
# bowled         34
# lbw            19
# run out        12
# -              12
# stumped         5
# hit wicket      1
# Name: Dismissal, dtype: int64

# %%
x.items
# Out:
# <bound method Series.items of caught        168
# not out        44
# bowled         34
# lbw            19
# run out        12
# -              12
# stumped         5
# hit wicket      1
# Name: Dismissal, dtype: int64>

# %%
y = df["Runs"].value_counts()
y
# Out:
# 0       16
# 2        8
# DNB      8
# 31       7
# 8        7
#         ..
# 68*      1
# 115      1
# 102      1
# 58*      1
# 101*     1
# Name: Runs, Length: 146, dtype: int64

# %%
for i in y.iteritems():
    print(i)
# Out:
# ('0', 16)
# ('2', 8)
# ('DNB', 8)
# ('31', 7)
# ('8', 7)
# ('9', 7)
# ('4', 6)
# ('16', 6)
# ('3', 6)
# ('54', 5)
# ('1', 5)
# ('11', 5)
# ('7', 5)
# ('18', 5)
# ('66', 5)
# ('12', 4)
# ('22', 4)
# ('107', 4)
# ('37', 4)
# ('TDNB', 4)
# ('20', 3)
# ('77', 3)
# ('117', 3)
# ('51', 3)
# ('21', 3)
# ('113', 3)
# ('5', 3)
# ('15', 3)
# ('45', 3)
# ('28', 3)
# ('82', 3)
# ('91', 2)
# ('23', 2)
# ('106', 2)
# ('6', 2)
# ('89', 2)
# ('26', 2)
# ('10', 2)
# ('36', 2)
# ('43', 2)
# ('75', 2)
# ('14', 2)
# ('25', 2)
# ('78', 2)
# ('46', 2)
# ('68', 2)
# ('55', 2)
# ('33*', 2)
# ('123', 2)
# ('35', 2)
# ('24', 2)
# ('59', 2)
# ('65', 2)
# ('100*', 2)
# ('85', 2)
# ('56', 2)
# ('38', 2)
# ('39', 1)
# ('92', 1)
# ('63', 1)
# ('88', 1)
# ('110*', 1)
# ('131', 1)
# ('82*', 1)
# ('111*', 1)
# ('29', 1)
# ('87', 1)
# ('32*', 1)
# ('96*', 1)
# ('76*', 1)
# ('81*', 1)
# ('122', 1)
# ('121', 1)
# ('71', 1)
# ('95', 1)
# ('103*', 1)
# ('114*', 1)
# ('120', 1)
# ('34*', 1)
# ('72', 1)
# ('67', 1)
# ...

# %%
df["DNB"] = df["Runs"].apply(lambda x : 1 if x == "DNB" or x == "TDNB" else 0)

# %%
df
# Out:
#     Runs Mins   BF 4s 6s      SR Pos Dismissal Inns     Opposition  \
# 0     12   33   22  1  0   54.54   2       lbw    1    v Sri Lanka
# 1     37   82   67  6  0   55.22   2    caught    2    v Sri Lanka
# 2     25   40   38  4  0   65.78   1   run out    1    v Sri Lanka
# 3     54   87   66  7  0   81.81   1    bowled    1    v Sri Lanka
# 4     31   45   46  3  1   67.39   1       lbw    2    v Sri Lanka
# ..   ...  ...  ... .. ..     ...  ..       ...  ...            ...
# 290  117  149  113  9  2  103.53   3    caught    1  v New Zealand
# 291   54   99   63  4  0   85.71   3    bowled    1    v Australia
# 292   24   42   32  2  0   75.00   3       lbw    2    v Sri Lanka
# 293   14   27   19  2  0   73.68   3       lbw    2    v Sri Lanka
# 294   20   29   18  4  0  111.11   3       lbw    2    v Sri Lanka
#
#             Ground   Start Date   Scorecard  is_not_out  DNB
# 0         Dambulla  18 Aug 2008  ODI # 2742           0    0
# ...

# %%
df["Runs"] = df["Runs"].str.replace("*","")
# Out:
# C:\Users\saikr\AppData\Local\Temp\ipykernel_12172\1021011674.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Runs"] = df["Runs"].str.replace("*","")

# %%
df[df["is_not_out"] == 1]
# Out:
#     Runs Mins   BF  4s 6s      SR Pos Dismissal Inns      Opposition  \
# 5      2    6    2   0  0  100.00   7   not out    1     v Sri Lanka
# 8     79  121  104   9  2   75.96   4   not out    2   v West Indies
# 17    71   98   68   9  0  104.41   3   not out    2     v Sri Lanka
# 18   102  128   95  11  0  107.36   3   not out    2    v Bangladesh
# 37    63   83   70   6  2   90.00   3   not out    2   v New Zealand
# 43    87  126   92   7  2   94.56   3   not out    2  v South Africa
# 45   100  113   83   8  2  120.48   4   not out    1    v Bangladesh
# 65   112  134   98  16  0  114.28   4   not out    2       v England
# 67    86    -   99  11  0   86.86   4   not out    2       v England
# 72    23   15   11   3  0  209.09   6   not out    1   v West Indies
# 81   133  133   86  16  2  154.65   4   not out    2     v Sri Lanka
# 88   128  187  119  12  1  107.56   3   not out    2     v Sri Lanka
# 95    77  110   79   9  2   97.46   3   not out    2       v England
# ...

# %%
df["Runs"] = df["Runs"].str.replace("TDNB",'0')
df["Runs"] = df["Runs"].str.replace("DNB",'0')

# %%
df["Runs"] = df["Runs"].astype(int)

# %%
df.dtypes
# Out:
# Runs           int32
# Mins          object
# BF            object
# 4s            object
# 6s            object
# SR            object
# Pos           object
# Dismissal     object
# Inns          object
# Opposition    object
# Ground        object
# Start Date    object
# Scorecard     object
# is_not_out     int64
# DNB            int64
# dtype: object

# %%
df["SR"] = df["SR"].replace("-","0")

# %%
df["SR"] = df["SR"].astype(float)

# %%
df.dtypes
# Out:
# Runs            int32
# Mins           object
# BF             object
# 4s             object
# 6s             object
# SR            float64
# Pos            object
# Dismissal      object
# Inns           object
# Opposition     object
# Ground         object
# Start Date     object
# Scorecard      object
# is_not_out      int64
# DNB             int64
# dtype: object

# %%
df["Opposition"] = df["Opposition"].str.replace("v ","")

# %%
df
# Out:
#      Runs Mins   BF 4s 6s      SR Pos Dismissal Inns   Opposition  \
# 0      12   33   22  1  0   54.54   2       lbw    1    Sri Lanka
# 1      37   82   67  6  0   55.22   2    caught    2    Sri Lanka
# 2      25   40   38  4  0   65.78   1   run out    1    Sri Lanka
# 3      54   87   66  7  0   81.81   1    bowled    1    Sri Lanka
# 4      31   45   46  3  1   67.39   1       lbw    2    Sri Lanka
# ..    ...  ...  ... .. ..     ...  ..       ...  ...          ...
# 290   117  149  113  9  2  103.53   3    caught    1  New Zealand
# 291    54   99   63  4  0   85.71   3    bowled    1    Australia
# 292    24   42   32  2  0   75.00   3       lbw    2    Sri Lanka
# 293    14   27   19  2  0   73.68   3       lbw    2    Sri Lanka
# 294    20   29   18  4  0  111.11   3       lbw    2    Sri Lanka
#
#             Ground   Start Date   Scorecard  is_not_out  DNB
# 0         Dambulla  18 Aug 2008  ODI # 2742           0    0
# ...

# %%
df["Start Date"] = pd.to_datetime(df["Start Date"])

# %%
df.dtypes
# Out:
# Runs                   int32
# Mins                  object
# BF                    object
# 4s                    object
# 6s                    object
# SR                   float64
# Pos                   object
# Dismissal             object
# Inns                  object
# Opposition            object
# Ground                object
# Start Date    datetime64[ns]
# Scorecard             object
# is_not_out             int64
# DNB                    int64
# dtype: object

# %%
df
# Out:
#      Runs Mins   BF 4s 6s      SR Pos Dismissal Inns   Opposition  \
# 0      12   33   22  1  0   54.54   2       lbw    1    Sri Lanka
# 1      37   82   67  6  0   55.22   2    caught    2    Sri Lanka
# 2      25   40   38  4  0   65.78   1   run out    1    Sri Lanka
# 3      54   87   66  7  0   81.81   1    bowled    1    Sri Lanka
# 4      31   45   46  3  1   67.39   1       lbw    2    Sri Lanka
# ..    ...  ...  ... .. ..     ...  ..       ...  ...          ...
# 290   117  149  113  9  2  103.53   3    caught    1  New Zealand
# 291    54   99   63  4  0   85.71   3    bowled    1    Australia
# 292    24   42   32  2  0   75.00   3       lbw    2    Sri Lanka
# 293    14   27   19  2  0   73.68   3       lbw    2    Sri Lanka
# 294    20   29   18  4  0  111.11   3       lbw    2    Sri Lanka
#
#             Ground Start Date   Scorecard  is_not_out  DNB
# 0         Dambulla 2008-08-18  ODI # 2742           0    0
# ...

# %%
df[df["Runs"] == 0]
# Out:
#      Runs Mins BF 4s 6s   SR Pos Dismissal Inns    Opposition         Ground  \
# 7       0    -  -  -  -  0.0   -         -    -     Australia      Centurion
# 14      0    -  -  -  -  0.0   -         -    -     Sri Lanka          Delhi
# 21      0    -  -  -  -  0.0   -         -    1  South Africa        Gwalior
# 23      0    3  0  0  0  0.0   3   run out    1      Zimbabwe       Bulawayo
# 31      0    5  3  0  0  0.0   3    caught    2     Sri Lanka       Dambulla
# 38      0    3  2  0  0  0.0   3    caught    2   New Zealand      Bengaluru
# 56      0    1  1  0  0  0.0   3       lbw    2   West Indies    North Sound
# 68      0    5  5  0  0  0.0   3    bowled    1       England   Eden Gardens
# 90      0    9  5  0  0  0.0   3    bowled    1      Pakistan        Chennai
# 97      0    1  1  0  0  0.0   3    caught    1       England     Dharamsala
# 111     0    -  -  -  -  0.0   -         -    2      Zimbabwe       Bulawayo
# ...

# %%
df.head()
# Out:
#    Runs Mins  BF 4s 6s     SR Pos Dismissal Inns Opposition         Ground  \
# 0    12   33  22  1  0  54.54   2       lbw    1  Sri Lanka       Dambulla
# 1    37   82  67  6  0  55.22   2    caught    2  Sri Lanka       Dambulla
# 2    25   40  38  4  0  65.78   1   run out    1  Sri Lanka  Colombo (RPS)
# 3    54   87  66  7  0  81.81   1    bowled    1  Sri Lanka  Colombo (RPS)
# 4    31   45  46  3  1  67.39   1       lbw    2  Sri Lanka  Colombo (RPS)
#
#   Start Date   Scorecard  is_not_out  DNB
# 0 2008-08-18  ODI # 2742           0    0
# 1 2008-08-20  ODI # 2745           0    0
# 2 2008-08-24  ODI # 2750           0    0
# 3 2008-08-27  ODI # 2755           0    0
# 4 2008-08-29  ODI # 2756           0    0

# %%
df.dtypes
# Out:
# Runs                   int32
# Mins                  object
# BF                    object
# 4s                    object
# 6s                    object
# SR                   float64
# Pos                   object
# Dismissal             object
# Inns                  object
# Opposition            object
# Ground                object
# Start Date    datetime64[ns]
# Scorecard             object
# is_not_out             int64
# DNB                    int64
# dtype: object

# %%
df["Mins"] = df["Mins"].str.replace("-","0")

# %%
df["BF"] = df["BF"].str.replace("-","0")

# %%
df["4s"] = df["4s"].str.replace("-","0")

# %%
df["6s"] = df["6s"].str.replace("-","0")

# %%
df["Mins"] = df["Mins"].astype(int)

# %%
df["BF"] = df["BF"].astype(int)

# %%
df["4s"] = df["4s"].astype(int)

# %%
df["6s"] = df["6s"].astype(int)

# %%
df.dtypes
# Out:
# Runs                   int32
# Mins                   int32
# BF                     int32
# 4s                     int32
# 6s                     int32
# SR                   float64
# Pos                   object
# Dismissal             object
# Inns                  object
# Opposition            object
# Ground                object
# Start Date    datetime64[ns]
# Scorecard             object
# is_not_out             int64
# DNB                    int64
# dtype: object

# %%
df.to_csv("virat_odi_stats_cleaned.csv", index = False)

# %% [markdown]
# ### Cleaning of T20I stats

# %%
t20_df = pd.read_csv("virat_t20_stats.csv")

# %%
t20_df
# Out:
#     Runs Mins  BF 4s 6s      SR Pos Dismissal Inns      Opposition  \
# 0    26*   30  21  3  1  123.80   5   not out    2      v Zimbabwe
# 1    DNB    -   -  -  -       -   -         -    2      v Zimbabwe
# 2     28   28  19  5  0  147.36   1    bowled    1  v South Africa
# 3     14   15  12  2  0  116.66   3    caught    1   v West Indies
# 4      4    5   5  0  0   80.00   4    caught    1       v England
# ..   ...  ...  .. .. ..     ...  ..       ...  ...             ...
# 120   24   41  24  0  1  100.00   2    caught    1   v Afghanistan
# 121   37   34  28  1  3  132.14   2    bowled    1    v Bangladesh
# 122    0    8   5  0  0    0.00   2    caught    1     v Australia
# 123    9   10   9  0  1  100.00   2    bowled    1       v England
# 124   76   87  59  6  2  128.81   2    caught    1  v South Africa
#
#             Ground   Start Date    Scorecard
# 0           Harare  12 Jun 2010   T20I # 182
# 1           Harare  13 Jun 2010   T20I # 183
# ...

# %%
t20_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Runs        125 non-null    object
#  1   Mins        125 non-null    object
#  2   BF          125 non-null    object
#  3   4s          125 non-null    object
#  4   6s          125 non-null    object
#  5   SR          125 non-null    object
#  6   Pos         125 non-null    object
#  7   Dismissal   125 non-null    object
#  8   Inns        125 non-null    object
#  9   Opposition  125 non-null    object
#  10  Ground      125 non-null    object
#  11  Start Date  125 non-null    object
#  12  Scorecard   125 non-null    object
# dtypes: object(13)
# memory usage: 12.8+ KB

# %%
t20_df.describe()
# Out:
#        Runs Mins   BF   4s   6s   SR  Pos Dismissal Inns   Opposition  Ground  \
# count   125  125  125  125  125  125  125       125  125          125     125
# unique   76   63   53   14    8   98    7         7    3           17      51
# top       0    -    -    0    0    -    3    caught    1  v Australia  Mirpur
# freq      7   30    8   27   53    8   80        65   70           23      11
#
#          Start Date   Scorecard
# count           125         125
# unique          125         125
# top     12 Jun 2010  T20I # 182
# freq              1           1

# %%
t20_df.dtypes
# Out:
# Runs          object
# Mins          object
# BF            object
# 4s            object
# 6s            object
# SR            object
# Pos           object
# Dismissal     object
# Inns          object
# Opposition    object
# Ground        object
# Start Date    object
# Scorecard     object
# dtype: object

# %%
t20_df["Start Date"] = pd.to_datetime(t20_df["Start Date"])

# %%
t20_df[t20_df["Runs"].apply(lambda x : "*" in x)]
# Out:
#      Runs Mins  BF  4s 6s      SR Pos Dismissal Inns      Opposition  \
# 0     26*   30  21   3  1  123.80   5   not out    2      v Zimbabwe
# 14    78*   61  61   8  2  127.86   3   not out    2      v Pakistan
# 21    36*   45  32   4  1  112.50   3   not out    2      v Pakistan
# 23    57*   66  50   3  1  114.00   3   not out    2    v Bangladesh
# 25    72*   67  44   5  2  163.63   3   not out    2  v South Africa
# 30    90*   71  55   9  2  163.63   3   not out    1     v Australia
# 31    59*   44  33   7  1  178.78   3   not out    1     v Australia
# 35    56*   85  47   7  0  119.14   3   not out    2     v Sri Lanka
# 37    41*   62  28   5  0  146.42   3   not out    2    v Bangladesh
# 39    55*   66  37   7  1  148.64   3   not out    2      v Pakistan
# 41    82*   78  51   9  2  160.78   3   not out    2     v Australia
# 42    89*   63  47  11  1  189.36   3   not out    1   v West Indies
# 50    22*   19  14   3  0  157.14   3   not out    2     v Australia
# ...

# %%
t20_df["is_not_out"] = t20_df["Dismissal"].apply(lambda x: 1 if x == "not out" else 0)

# %%
t20_df.head()
# Out:
#   Runs Mins  BF 4s 6s      SR Pos Dismissal Inns      Opposition  \
# 0  26*   30  21  3  1  123.80   5   not out    2      v Zimbabwe
# 1  DNB    -   -  -  -       -   -         -    2      v Zimbabwe
# 2   28   28  19  5  0  147.36   1    bowled    1  v South Africa
# 3   14   15  12  2  0  116.66   3    caught    1   v West Indies
# 4    4    5   5  0  0   80.00   4    caught    1       v England
#
#           Ground Start Date   Scorecard  is_not_out
# 0         Harare 2010-06-12  T20I # 182           1
# 1         Harare 2010-06-13  T20I # 183           0
# 2         Durban 2011-01-09  T20I # 196           0
# 3  Port of Spain 2011-06-04  T20I # 200           0
# 4     Manchester 2011-08-31  T20I # 204           0

# %%
for i in t20_df["Runs"].iteritems():
    print(i)
# Out:
# (0, '26*')
# (1, 'DNB')
# (2, '28')
# (3, '14')
# (4, '4')
# (5, '15')
# (6, '22')
# (7, '31')
# (8, 'DNB')
# (9, '68')
# (10, '70')
# (11, '50')
# (12, '40')
# (13, '15')
# (14, '78*')
# (15, '2')
# (16, '21')
# (17, '38')
# (18, '9')
# (19, '27')
# (20, '29')
# (21, '36*')
# (22, '54')
# (23, '57*')
# (24, '23')
# (25, '72*')
# (26, '77')
# (27, '66')
# (28, '43')
# (29, '1')
# (30, '90*')
# (31, '59*')
# (32, '50')
# (33, '7')
# (34, '49')
# (35, '56*')
# (36, 'DNB')
# (37, '41*')
# (38, '23')
# (39, '55*')
# (40, '24')
# (41, '82*')
# (42, '89*')
# (43, '16')
# (44, 'DNB')
# (45, '29')
# (46, '21')
# (47, '2')
# (48, '39')
# (49, '82')
# (50, '22*')
# (51, '0')
# (52, '26*')
# (53, '65')
# (54, '13')
# (55, '26')
# (56, '1')
# (57, '0')
# (58, '9')
# (59, '20*')
# (60, '47')
# (61, '43')
# (62, '4')
# (63, 'TDNB')
# (64, '61*')
# (65, '24')
# (66, '72*')
# (67, '19')
# (68, '28')
# (69, '59')
# (70, '72*')
# (71, '9')
# (72, '94*')
# (73, '19')
# (74, '70*')
# (75, 'TDNB')
# ...

# %%
t20_df["DNB"] = t20_df["Runs"].apply(lambda x : 1 if x == "DNB" or x == "TDNB" else 0)

# %%
t20_df.head()
# Out:
#   Runs Mins  BF 4s 6s      SR Pos Dismissal Inns      Opposition  \
# 0  26*   30  21  3  1  123.80   5   not out    2      v Zimbabwe
# 1  DNB    -   -  -  -       -   -         -    2      v Zimbabwe
# 2   28   28  19  5  0  147.36   1    bowled    1  v South Africa
# 3   14   15  12  2  0  116.66   3    caught    1   v West Indies
# 4    4    5   5  0  0   80.00   4    caught    1       v England
#
#           Ground Start Date   Scorecard  is_not_out  DNB
# 0         Harare 2010-06-12  T20I # 182           1    0
# 1         Harare 2010-06-13  T20I # 183           0    1
# 2         Durban 2011-01-09  T20I # 196           0    0
# 3  Port of Spain 2011-06-04  T20I # 200           0    0
# 4     Manchester 2011-08-31  T20I # 204           0    0

# %%
t20_df["Runs"] = t20_df["Runs"].str.replace("TDNB","0")
t20_df["Runs"] = t20_df["Runs"].str.replace("DNB","0")

# %%
t20_df[t20_df["DNB"] == 1]
# Out:
#    Runs Mins BF 4s 6s SR Pos Dismissal Inns      Opposition        Ground  \
# 1     0    -  -  -  -  -   -         -    2      v Zimbabwe        Harare
# 8     0    -  -  -  -  -   -         -    2  v South Africa  Johannesburg
# 36    0    -  -  -  -  -   -         -    2        v U.A.E.        Mirpur
# 44    0    -  -  -  -  -   -         -    2   v West Indies    Lauderhill
# 63    0    -  -  -  -  -   -         -    -     v Australia     Melbourne
# 75    0    -  -  -  -  -   -         -    -     v Sri Lanka      Guwahati
# 92    0    -  -  -  -  -   -         -    1   v Afghanistan     Abu Dhabi
# 94    0    -  -  -  -  -   -         -    2       v Namibia  Dubai (DICS)
#
#    Start Date    Scorecard  is_not_out  DNB
# 1  2010-06-13   T20I # 183           0    1
# 8  2012-03-30   T20I # 242           0    1
# 36 2016-03-03   T20I # 517           0    1
# 44 2016-08-28   T20I # 563           0    1
# 63 2018-11-23   T20I # 713           0    1
# ...

# %%
t20_df["Runs"] = t20_df["Runs"].str.replace("*","")
# Out:
# C:\Users\saikr\AppData\Local\Temp\ipykernel_12172\650478123.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   t20_df["Runs"] = t20_df["Runs"].str.replace("*","")

# %%
t20_df.dtypes
# Out:
# Runs                  object
# Mins                  object
# BF                    object
# 4s                    object
# 6s                    object
# SR                    object
# Pos                   object
# Dismissal             object
# Inns                  object
# Opposition            object
# Ground                object
# Start Date    datetime64[ns]
# Scorecard             object
# is_not_out             int64
# DNB                    int64
# dtype: object

# %%
t20_df["Mins"] = t20_df["Mins"].str.replace("-","0")
t20_df["Runs"] = t20_df["Runs"].str.replace("-","0")
t20_df["BF"] = t20_df["BF"].str.replace("-","0")
t20_df["SR"] = t20_df["SR"].str.replace("-","0")
t20_df["4s"] = t20_df["4s"].str.replace("-","0")
t20_df["6s"] = t20_df["6s"].str.replace("-","0")

# %%
t20_df["Runs"] = t20_df["Runs"].astype(int)
t20_df["Mins"] = t20_df["Mins"].astype(int)
t20_df["SR"] = t20_df["SR"].astype(float)
t20_df["4s"] = t20_df["4s"].astype(int)
t20_df["6s"] = t20_df["6s"].astype(int)
t20_df["BF"] = t20_df["BF"].astype(int)

# %%
df.dtypes
# Out:
# Runs                   int32
# Mins                   int32
# BF                     int32
# 4s                     int32
# 6s                     int32
# SR                   float64
# Pos                   object
# Dismissal             object
# Inns                  object
# Opposition            object
# Ground                object
# Start Date    datetime64[ns]
# Scorecard             object
# is_not_out             int64
# DNB                    int64
# dtype: object

# %%
t20_df.head()
# Out:
#    Runs  Mins  BF  4s  6s      SR Pos Dismissal Inns      Opposition  \
# 0    26    30  21   3   1  123.80   5   not out    2      v Zimbabwe
# 1     0     0   0   0   0    0.00   -         -    2      v Zimbabwe
# 2    28    28  19   5   0  147.36   1    bowled    1  v South Africa
# 3    14    15  12   2   0  116.66   3    caught    1   v West Indies
# 4     4     5   5   0   0   80.00   4    caught    1       v England
#
#           Ground Start Date   Scorecard  is_not_out  DNB
# 0         Harare 2010-06-12  T20I # 182           1    0
# 1         Harare 2010-06-13  T20I # 183           0    1
# 2         Durban 2011-01-09  T20I # 196           0    0
# 3  Port of Spain 2011-06-04  T20I # 200           0    0
# 4     Manchester 2011-08-31  T20I # 204           0    0

# %%
t20_df["Opposition"] = t20_df["Opposition"].str.replace("v ","")

# %%
t20_df.head()
# Out:
#    Runs  Mins  BF  4s  6s      SR Pos Dismissal Inns    Opposition  \
# 0    26    30  21   3   1  123.80   5   not out    2      Zimbabwe
# 1     0     0   0   0   0    0.00   -         -    2      Zimbabwe
# 2    28    28  19   5   0  147.36   1    bowled    1  South Africa
# 3    14    15  12   2   0  116.66   3    caught    1   West Indies
# 4     4     5   5   0   0   80.00   4    caught    1       England
#
#           Ground Start Date   Scorecard  is_not_out  DNB
# 0         Harare 2010-06-12  T20I # 182           1    0
# 1         Harare 2010-06-13  T20I # 183           0    1
# 2         Durban 2011-01-09  T20I # 196           0    0
# 3  Port of Spain 2011-06-04  T20I # 200           0    0
# 4     Manchester 2011-08-31  T20I # 204           0    0

# %%
t20_df.to_csv("virat_t20_stats_cleaned.csv",index = False)

# %% [markdown]
# ### Cleaning of Test Stats

# %%
test_df = pd.read_csv("virat_test_stats.csv")

# %%
test_df.head()
# Out:
#   Runs Mins   BF 4s 6s     SR Pos Dismissal Inns     Opposition      Ground  \
# 0    4   13   10  1  0  40.00   5    caught    1  v West Indies    Kingston
# 1   15   72   54  2  0  27.77   5    caught    3  v West Indies    Kingston
# 2    0    1    2  0  0   0.00   5    caught    1  v West Indies  Bridgetown
# 3   27  118  107  1  1  25.23   5    caught    3  v West Indies  Bridgetown
# 4   30   62   53  2  0  56.60   5    caught    2  v West Indies      Roseau
#
#     Start Date    Scorecard
# 0  20 Jun 2011  Test # 1997
# 1  20 Jun 2011  Test # 1997
# 2  28 Jun 2011  Test # 1998
# 3  28 Jun 2011  Test # 1998
# 4   6 Jul 2011  Test # 1999

# %%
test_df[test_df["Runs"].apply(lambda x : "*" in x or "DNB" in x or "TDNB" in x)]
# Out:
#      Runs Mins   BF  4s 6s      SR Pos Dismissal Inns      Opposition  \
# 5     DNB    -    -   -  -       -   -         -    4   v West Indies
# 18    51*  130   82   9  0   62.19   5   not out    4   v New Zealand
# 20    14*   17   21   3  0   66.66   3   not out    4       v England
# 27    DNB    -    -   -  -       -   -         -    4     v Australia
# 29    67*  157  129   7  1   51.93   5   not out    2     v Australia
# 42   105*  195  135  15  1   77.77   4   not out    4   v New Zealand
# 70    DNB    -    -   -  -       -   -         -    2  v South Africa
# 79   TDNB    -    -   -  -       -   -         -    -   v West Indies
# 87    49*  129   98   6  0   50.00   4   not out    4       v England
# 91     6*   11   11   0  0   54.54   4   not out    4       v England
# 102  103*  158  136   5  1   75.73   4   not out    3     v Sri Lanka
# 106  104*  208  119  12  2   87.39   4   not out    3     v Sri Lanka
# ...

# %%
test_df["is_not_out"] = test_df["Dismissal"].apply(lambda x : 1 if x == "not out" else 0)

# %%
test_df.head()
# Out:
#   Runs Mins   BF 4s 6s     SR Pos Dismissal Inns     Opposition      Ground  \
# 0    4   13   10  1  0  40.00   5    caught    1  v West Indies    Kingston
# 1   15   72   54  2  0  27.77   5    caught    3  v West Indies    Kingston
# 2    0    1    2  0  0   0.00   5    caught    1  v West Indies  Bridgetown
# 3   27  118  107  1  1  25.23   5    caught    3  v West Indies  Bridgetown
# 4   30   62   53  2  0  56.60   5    caught    2  v West Indies      Roseau
#
#     Start Date    Scorecard  is_not_out
# 0  20 Jun 2011  Test # 1997           0
# 1  20 Jun 2011  Test # 1997           0
# 2  28 Jun 2011  Test # 1998           0
# 3  28 Jun 2011  Test # 1998           0
# 4   6 Jul 2011  Test # 1999           0

# %%
test_df["DNB"] = test_df["Runs"].apply(lambda x : 1 if x == "DNB" or x == "TDNB" else 0)

# %%
test_df.head()
# Out:
#   Runs Mins   BF 4s 6s     SR Pos Dismissal Inns     Opposition      Ground  \
# 0    4   13   10  1  0  40.00   5    caught    1  v West Indies    Kingston
# 1   15   72   54  2  0  27.77   5    caught    3  v West Indies    Kingston
# 2    0    1    2  0  0   0.00   5    caught    1  v West Indies  Bridgetown
# 3   27  118  107  1  1  25.23   5    caught    3  v West Indies  Bridgetown
# 4   30   62   53  2  0  56.60   5    caught    2  v West Indies      Roseau
#
#     Start Date    Scorecard  is_not_out  DNB
# 0  20 Jun 2011  Test # 1997           0    0
# 1  20 Jun 2011  Test # 1997           0    0
# 2  28 Jun 2011  Test # 1998           0    0
# 3  28 Jun 2011  Test # 1998           0    0
# 4   6 Jul 2011  Test # 1999           0    0

# %%
test_df[test_df["Runs"].apply(lambda x : "*" in x or "DNB" in x or "TDNB" in x)]
# Out:
#      Runs Mins   BF  4s 6s      SR Pos Dismissal Inns      Opposition  \
# 5     DNB    -    -   -  -       -   -         -    4   v West Indies
# 18    51*  130   82   9  0   62.19   5   not out    4   v New Zealand
# 20    14*   17   21   3  0   66.66   3   not out    4       v England
# 27    DNB    -    -   -  -       -   -         -    4     v Australia
# 29    67*  157  129   7  1   51.93   5   not out    2     v Australia
# 42   105*  195  135  15  1   77.77   4   not out    4   v New Zealand
# 70    DNB    -    -   -  -       -   -         -    2  v South Africa
# 79   TDNB    -    -   -  -       -   -         -    -   v West Indies
# 87    49*  129   98   6  0   50.00   4   not out    4       v England
# 91     6*   11   11   0  0   54.54   4   not out    4       v England
# 102  103*  158  136   5  1   75.73   4   not out    3     v Sri Lanka
# 106  104*  208  119  12  2   87.39   4   not out    3     v Sri Lanka
# ...

# %%
test_df["Runs"] = test_df["Runs"].str.replace("*","")
test_df["Runs"] = test_df["Runs"].str.replace("TDNB","0")
test_df["Runs"] = test_df["Runs"].str.replace("DNB","0")
# Out:
# C:\Users\saikr\AppData\Local\Temp\ipykernel_12172\4087393296.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   test_df["Runs"] = test_df["Runs"].str.replace("*","")

# %%
test_df.head()
# Out:
#   Runs Mins   BF 4s 6s     SR Pos Dismissal Inns     Opposition      Ground  \
# 0    4   13   10  1  0  40.00   5    caught    1  v West Indies    Kingston
# 1   15   72   54  2  0  27.77   5    caught    3  v West Indies    Kingston
# 2    0    1    2  0  0   0.00   5    caught    1  v West Indies  Bridgetown
# 3   27  118  107  1  1  25.23   5    caught    3  v West Indies  Bridgetown
# 4   30   62   53  2  0  56.60   5    caught    2  v West Indies      Roseau
#
#     Start Date    Scorecard  is_not_out  DNB
# 0  20 Jun 2011  Test # 1997           0    0
# 1  20 Jun 2011  Test # 1997           0    0
# 2  28 Jun 2011  Test # 1998           0    0
# 3  28 Jun 2011  Test # 1998           0    0
# 4   6 Jul 2011  Test # 1999           0    0

# %%
test_df[(test_df["is_not_out"] == 1) | (test_df["DNB"] == 1)]
# Out:
#     Runs Mins   BF  4s 6s      SR Pos Dismissal Inns      Opposition  \
# 5      0    -    -   -  -       -   -         -    4   v West Indies
# 18    51  130   82   9  0   62.19   5   not out    4   v New Zealand
# 20    14   17   21   3  0   66.66   3   not out    4       v England
# 27     0    -    -   -  -       -   -         -    4     v Australia
# 29    67  157  129   7  1   51.93   5   not out    2     v Australia
# 42   105  195  135  15  1   77.77   4   not out    4   v New Zealand
# 70     0    -    -   -  -       -   -         -    2  v South Africa
# 79     0    -    -   -  -       -   -         -    -   v West Indies
# 87    49  129   98   6  0   50.00   4   not out    4       v England
# 91     6   11   11   0  0   54.54   4   not out    4       v England
# 102  103  158  136   5  1   75.73   4   not out    3     v Sri Lanka
# 106  104  208  119  12  2   87.39   4   not out    3     v Sri Lanka
# 128    0    -    -   -  -       -   -         -    4   v West Indies
# ...

# %%
test_df["Opposition"] = test_df["Opposition"].str.replace("v ","")

# %%
test_df["Mins"] = test_df["Mins"].str.replace("-","0")
test_df["BF"] = test_df["BF"].str.replace("-","0")
test_df["4s"] = test_df["4s"].str.replace("-","0")
test_df["6s"] = test_df["6s"].str.replace("-","0")
test_df["SR"] = test_df["SR"].str.replace("-","0")

# %%
test_df["Runs"] = test_df["Runs"].astype(int)
test_df["Mins"] = test_df["Mins"].astype(int)
test_df["BF"] = test_df["BF"].astype(int)
test_df["4s"] = test_df["4s"].astype(int)
test_df["6s"] = test_df["6s"].astype(int)
test_df["SR"] = test_df["SR"].astype(float)

# %%
test_df.dtypes
# Out:
# Runs            int32
# Mins            int32
# BF              int32
# 4s              int32
# 6s              int32
# SR            float64
# Pos            object
# Dismissal      object
# Inns           object
# Opposition     object
# Ground         object
# Start Date     object
# Scorecard      object
# is_not_out      int64
# DNB             int64
# dtype: object

# %%
test_df["Start Date"] = pd.to_datetime(test_df["Start Date"])

# %%
test_df.dtypes
# Out:
# Runs                   int32
# Mins                   int32
# BF                     int32
# 4s                     int32
# 6s                     int32
# SR                   float64
# Pos                   object
# Dismissal             object
# Inns                  object
# Opposition            object
# Ground                object
# Start Date    datetime64[ns]
# Scorecard             object
# is_not_out             int64
# DNB                    int64
# dtype: object

# %%
test_df.head()
# Out:
#    Runs  Mins   BF  4s  6s     SR Pos Dismissal Inns   Opposition      Ground  \
# 0     4    13   10   1   0  40.00   5    caught    1  West Indies    Kingston
# 1    15    72   54   2   0  27.77   5    caught    3  West Indies    Kingston
# 2     0     1    2   0   0   0.00   5    caught    1  West Indies  Bridgetown
# 3    27   118  107   1   1  25.23   5    caught    3  West Indies  Bridgetown
# 4    30    62   53   2   0  56.60   5    caught    2  West Indies      Roseau
#
#   Start Date    Scorecard  is_not_out  DNB
# 0 2011-06-20  Test # 1997           0    0
# 1 2011-06-20  Test # 1997           0    0
# 2 2011-06-28  Test # 1998           0    0
# 3 2011-06-28  Test # 1998           0    0
# 4 2011-07-06  Test # 1999           0    0

# %%
test_df.to_csv("virat_test_stats_cleaned.csv", index = False)
